# %% [markdown]
# <a href="https://colab.research.google.com/github/sanusi009/Newproject/blob/main/project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from sklearn.impute import SimpleImputer

# %%
N = 30
x = np.arange(N)
y = 4 * x - 7 + (5*np.random.randn(N))
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
model.fit(x[:, np.newaxis], y)
yfit = model.predict(x[:, np.newaxis])
plt.scatter(x, y)
plt.plot(x, yfit,color='red');

# %%
from sklearn.datasets import make_blobs 
X, y = make_blobs(n_samples=500, centers=3,cluster_std=1.2)
plt.scatter(X[:, 0], X[:, 1], c=y,cmap='autumn');

# %%
sns.set()
X = pd.Series(50*np.random.randn(5000))
Y = pd.Series(200*np.random.randn(5000))
Z = pd.Series(100*np.random.randn(5000)+500)
data = pd.DataFrame({'X':X, 'Y':Y, 'Z':Z})
#data.head()
for col in data.columns:
    plt.hist(data[col], density=True,alpha=0.5,)
    plt.legend(('X','Y','Z'))
    sns.kdeplot(data[col], shade=True)

# %%
for col in data.columns:
    sns.distplot(data[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.svm import SVC

# %%
md1 = SVC(gamma = 'auto')
md1.fit(X_train,y_train)

# %%
y_predict = md1.predict(X_test)

# %%
acc = 100*np.sum(y_predict == y_test)/y_test.size
print("Accuracy is :", acc, "%")
# Out:
# Accuracy is : 95.75757575757575 %

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
md1 = RandomForestClassifier(n_estimators = 20)
md1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_predict = md1.predict(X_test)
acc = 100*np.sum(y_predict == y_test)/y_test.size
print("Accuracy is :", acc, "%")
# Out:
# Accuracy is : 95.75757575757575 %

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(0,50,(5,10)),
                 columns=list('ABCDEFGHIJ'))

# %%
df
# Out:
#     A   B   C   D   E   F   G   H   I   J
# 0  28  21  38   8  45  21  39  19  40  21
# 1  27  39  17  28  27  22  21  43  22  37
# 2  36  11  16  12   1  11  22   4  38  47
# 3   9  15  24  39   8  44  14  45  14  21
# 4  14  40  34  23  34  43  18  26  26  17

# %%
df.where(df<5) 
df.where(df>30)

# %%
fig,ax = plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].imshow(np.random.rand(200,200),cmap='inferno_r')
        ax[i,j].set(xticks=[],yticks=[])

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=70)

# %%
plt.imshow(faces.images[3])

# %%
fig,ax = plt.subplots(4,5,figsize=(4,3),sharex='col',sharey='row')
k = 0
for i in range(4):
    for j in range(5):
        ax[i,j].imshow(faces.images[k],cmap='bone')
        ax[i,j].set(xticks=[],yticks=[])
        k+=1

# %%
fig,ax = plt.subplots(2,4,figsize=(4,3),sharex='col',sharey='row')
k = 0
for i in range(2):
    for j in range(4):
        ax[i,j].imshow(faces.images[k],cmap='coolwarm')
        ax[i,j].set(xticks=[],yticks=[])
        k+=1

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4*np.pi,4*np.pi,100)
Z = np.linspace(-2,2,100)
r = Z**2+1
X = r*np.sin(theta)
Y = r*np.cos(theta)
ax.plot(X,Y,Z,label='3D curve')
ax.legend()
ax.set_title('3D curve')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0.5, 0, 'Y')

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.gca(projection='3d')
X = np.random.normal(0,5,50)
Y = np.random.normal(0,5,50)
Z = np.random.normal(0,5,50)
ax.scatter(X,Y,Z, c='g',marker='.', alpha=0.7)
X = np.random.normal(10,9,70)
Y = np.random.normal(10,9,70)
Z = np.random.normal(10,9,70)
ax.scatter(X,Y,Z, c='y',marker='+', alpha=0.7)

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
X,Y,Z = axes3d.get_test_data(0.008)

# %%
X,Y = np.meshgrid(np.linspace(-2,2,500),np.linspace(-2,2,500))
Z = 2*np.sin(X)-4*np.cos(X*Y)+3

# %%
fig = plt.figure(figsize=(4,3))
ax = fig.gca(projection='3d')
curve3D = ax.plot_surface(X,Y,Z,cmap=plt.cm.coolwarm, alpha=1, label='curve3D')
curve3D._facecolors2d=curve3D._facecolors3d
curve3D._edgecolors2d=curve3D._edgecolors3d
ax.legend()
ax.set_title('3D curve')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0.5, 0, 'Y')

# %%
df = pd.DataFrame({'X':np.random.normal(0,2,1000),'Y':np.random.normal(3,5,1000),'Z':np.random.normal(-4,10,1000)})

# %%
df.head()
# Out:
#           X          Y          Z
# 0 -4.313437   5.914550  -9.908946
# 1 -2.028107  11.895843  11.167480
# 2 -0.273747   0.770505  -4.501732
# 3 -2.084294  10.845076  -0.806866
# 4  2.543463  11.477115   0.684484

# %%
plt.figure(figsize=(4,3))
for col in df.columns:
    plt.hist(df[col],density=True,alpha=0.5,bins=30,)
    plt.legend(('X','Y','Z'))
    sns.kdeplot(df[col],shade=True)

# %%
plt.figure(figsize=(4,3))
for col in df.columns:
  sns.distplot(df[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
with sns.axes_style('white'):
    sns.jointplot('X','Y',df,kind='kde')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris,hue='species')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x='sepal_width',y='petal_length',data=iris,hue='sepal_length',style='species',ci=None,markers=True)
